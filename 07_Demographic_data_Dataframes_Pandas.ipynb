# %% [markdown]
# <a href="https://colab.research.google.com/github/suryakanthPS/DS-Workbooks/blob/main/07_Demographic_data_Dataframes_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
stats = pd.read_csv("/content/DemographicData.csv")

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
#for number of rows
#len(dataframe)
len(stats)
# Out:
# 195

# %%
#to see columns
#datsframe.coloumn
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
#for number of colomns
#len(dataframe.columns)
len(stats.columns)
# Out:
# 5

# %%
#for viewing top rows
#dataframe.head() brings top 5 rows
#dataframe.head(7) brings top 7 rows
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#bottom rows
stats.tail()
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
stats.head(10)
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244         78.9000
# 1           Afghanistan          AFG      35.253          5.9000
# 2                Angola          AGO      45.985         19.1000
# 3               Albania          ALB      12.877         57.2000
# 4  United Arab Emirates          ARE      11.044         88.0000
# 5             Argentina          ARG      17.716         59.9000
# 6               Armenia          ARM      13.308         41.9000
# 7   Antigua and Barbuda          ATG      16.447         63.4000
# 8             Australia          AUS      13.200         83.0000
# 9               Austria          AUT       9.400         80.6188
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# ...

# %%
#getting information on columns
#dataframe.info()
#object refers to string and float refers to decimal 
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
#statistics data from dataframe
#statistics only apply on numerical coloumns here birthrate and int users are has decimal value
stats.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
#renaming columns_renaming without space
stats.columns=['CountryName','CountryCode', 'BirthRate','InternetUsers','IncomeGroup']

# %%
stats
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
#to print only selected rows
stats[10:15]
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 10    Azerbaijan         AZE     18.300        58.7000  Upper middle income
# 11       Burundi         BDI     44.151         1.3000           Low income
# 12       Belgium         BEL     11.200        82.1702          High income
# 13         Benin         BEN     36.440         4.9000           Low income
# 14  Burkina Faso         BFA     40.551         9.1000           Low income

# %%
#columns
stats.columns[2:3]
# Out:
# Index(['BirthRate'], dtype='object')

# %%
stats.columns[2:4]
# Out:
# Index(['BirthRate', 'InternetUsers'], dtype='object')

# %%
stats.columns[2:]
# Out:
# Index(['BirthRate', 'InternetUsers', 'IncomeGroup'], dtype='object')

# %%
#columns subsetting
#we are using double aquare brackets bcoz we use one square bracket for list and another square braket for extracting the list
#.head is for top most 5 rows and .tail is for bottom 5 rows
stats[['CountryName']].head()
# Out:
#             CountryName
# 0                 Aruba
# 1           Afghanistan
# 2                Angola
# 3               Albania
# 4  United Arab Emirates

# %%
stats[['CountryName','BirthRate']].head()
# Out:
#             CountryName  BirthRate
# 0                 Aruba     10.244
# 1           Afghanistan     35.253
# 2                Angola     45.985
# 3               Albania     12.877
# 4  United Arab Emirates     11.044

# %%
#subsetting rows and columns
stats[4:8][['CountryName','BirthRate']]
# Out:
#             CountryName  BirthRate
# 4  United Arab Emirates     11.044
# 5             Argentina     17.716
# 6               Armenia     13.308
# 7   Antigua and Barbuda     16.447

# %%
#instead of tying the list or column names we can use iloc syntax
stats.iloc[1]
# Out:
# CountryName      Afghanistan
# CountryCode              AFG
# BirthRate             35.253
# InternetUsers            5.9
# IncomeGroup       Low income
# Name: 1, dtype: object

# %%
stats.iloc[:,0:3]
# Out:
#               CountryName CountryCode  BirthRate
# 0                   Aruba         ABW     10.244
# 1             Afghanistan         AFG     35.253
# 2                  Angola         AGO     45.985
# 3                 Albania         ALB     12.877
# 4    United Arab Emirates         ARE     11.044
# ..                    ...         ...        ...
# 190           Yemen, Rep.         YEM     32.947
# 191          South Africa         ZAF     20.850
# 192      Congo, Dem. Rep.         COD     42.394
# 193                Zambia         ZMB     40.471
# 194              Zimbabwe         ZWE     35.715
#
# [195 rows x 3 columns]

# %%
#we can do basic mathematical operation with data frames
#we can add a column and specify the coloumn name and operation
stats['NewColumn'] = stats.InternetUsers / stats.BirthRate

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup  NewColumn
# 0          High income   7.702070
# 1           Low income   0.167362
# 2  Upper middle income   0.415353
# 3  Upper middle income   4.442028
# 4          High income   7.968127

# %%
#we can remove a coloumn
#dataframe.drop['colunname,axisvalue]
stats = stats.drop('NewColumn', 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
stats
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
#filtering of dataframes
#we can setup filters for vlues in coloumn giving cond and filter out rows that do not satisfy to the cond 
stats[stats.InternetUsers <=2]
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income

# %%
#filtering gives true or false values
Filter = stats.InternetUsers <=2
Filter
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
#we can do multiple Filters also
#use round brackets for each filters seperated by &
stats[(stats.InternetUsers <=2) & (stats.BirthRate > 40)]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11      Burundi         BDI     44.151            1.3  Low income
# 127       Niger         NER     49.661            1.7  Low income
# 156     Somalia         SOM     43.891            1.5  Low income

# %% [markdown]
# **Introduction to Seaborn**

# %%
#matplot lib is for basic visualization
#seaborn is for high end visualization
#pandas is for data analytics of the data set
#numpy is to perforn numerical or statistical function in datas
#scikitlearn is for alla the most machine learning algorithm

from pandas.errors import InvalidIndexError
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize']=8,8
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
#12.27
visual1 = sns.distplot(stats['InternetUsers'],bins=40)

# %%
from matplotlib import figure
#boxplot
visualbox2=sns.boxplot(data=stats, x='IncomeGroup', y='BirthRate')
plt.rcParams['figure.figsize'] = 20,10

# %%
#lmplot means linear modal plot
visualbox3=sns.lmplot(data=stats, x='InternetUsers', y='BirthRate')

# %%
#removed regression line
visualbox3=sns.lmplot(data=stats, x='InternetUsers', y='BirthRate', fit_reg=False)

# %%
#hue refers to color code to differentiate the colors of each income group
visualbox3=sns.lmplot(data=stats, x='InternetUsers', y='BirthRate', fit_reg=False, hue='IncomeGroup')

# %%
visualbox3=sns.scatterplot(data=stats, x='InternetUsers', y='BirthRate', hue='IncomeGroup')

# %%
CountryCode = "CountryCode"
for name in stats[CountryCode]: #first level
  if name[0]=="A":
    print(stats.loc[stats['CountryCode'] == name ])
# Out:
#   CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0       Aruba         ABW     10.244           78.9  High income
#    CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 1  Afghanistan         AFG     35.253            5.9  Low income
#   CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 2      Angola         AGO     45.985           19.1  Upper middle income
#   CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 3     Albania         ALB     12.877           57.2  Upper middle income
#             CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 4  United Arab Emirates         ARE     11.044           88.0  High income
#   CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 5   Argentina         ARG     17.716           59.9  High income
#   CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# ...
